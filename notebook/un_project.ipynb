# %%
import pandas as pd   
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %% [markdown]
# 4. Using the pandas `read_csv()` method, read the GDP dataset into your notebook as a DataFrame called `gdp_df`. Take a look at the first few and last few rows to familiarize yourself with what is contained in this dataset.

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]

# %% [markdown]
# 5. How many rows and columns are in `gdp_df`? What are the data types of each column? 7176 rows and 4 columns

# %% [markdown]
# 6. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
gdp_demo = gdp_df.drop(columns = ['Value Footnotes'])

# %%
gdp_demo
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2020  1970.560169
# 1        Afghanistan  2019  2065.036235
# 2        Afghanistan  2018  2033.804389
# 3        Afghanistan  2017  2058.400221
# 4        Afghanistan  2016  2057.067978
# ...              ...   ...          ...
# 7171        Zimbabwe  1994  2603.927369
# 7172        Zimbabwe  1993  2420.092791
# 7173        Zimbabwe  1992  2437.152908
# 7174        Zimbabwe  1991  2733.696626
# 7175        Zimbabwe  1990  2652.129209
#
# [7176 rows x 3 columns]

# %%
gdp_demo.columns = ['Country', 'Year', 'GDP_Per_Capita']

# %%
gdp_demo.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2020     1970.560169
# 1  Afghanistan  2019     2065.036235
# 2  Afghanistan  2018     2033.804389
# 3  Afghanistan  2017     2058.400221
# 4  Afghanistan  2016     2057.067978

# %% [markdown]
# 7. How many countries have data for all years? Which countries are missing many years of data?
# Look at the number of observations per year. What do you notice?

# %%
gdp_demo.tail()
# Out:
#        Country  Year  GDP_Per_Capita
# 7171  Zimbabwe  1994     2603.927369
# 7172  Zimbabwe  1993     2420.092791
# 7173  Zimbabwe  1992     2437.152908
# 7174  Zimbabwe  1991     2733.696626
# 7175  Zimbabwe  1990     2652.129209

# %%
max_year = gdp_demo['Year'].max()

# %%
max_year
# Out:
# 2020

# %%
min_year = gdp_demo['Year'].min()

# %%
min_year
# Out:
# 1990

# %%
gdp_demo.Year.head()
# Out:
# 0    2020
# 1    2019
# 2    2018
# 3    2017
# 4    2016
# Name: Year, dtype: int64

# %%
all_years = gdp_demo[(gdp_demo.Year > 1989) & (gdp_demo.Year < 2021)]

# %%
all_years.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2020     1970.560169
# 1  Afghanistan  2019     2065.036235
# 2  Afghanistan  2018     2033.804389
# 3  Afghanistan  2017     2058.400221
# 4  Afghanistan  2016     2057.067978

# %%
all_years
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
all_years.Country.value_counts()
# Out:
# Least developed countries: UN classification    31
# Niger                                           31
# Middle East & North Africa (IDA & IBRD)         31
# Middle income                                   31
# Mongolia                                        31
#                                                 ..
# Kosovo                                          13
# Turks and Caicos Islands                        10
# Sint Maarten (Dutch part)                       10
# Somalia                                          8
# Djibouti                                         8
# Name: Country, Length: 242, dtype: int64

# %%
all_years['Country'].value_counts().loc[lambda x : x<31]
# Out:
# Turkmenistan                 30
# Hungary                      30
# Slovak Republic              29
# Cambodia                     28
# West Bank and Gaza           27
# Bosnia and Herzegovina       27
# Slovenia                     26
# Latvia                       26
# Israel                       26
# Lithuania                    26
# Serbia                       26
# Moldova                      26
# Iceland                      26
# Croatia                      26
# Estonia                      26
# Kuwait                       26
# Maldives                     26
# Canada                       24
# Montenegro                   24
# Small states                 24
# San Marino                   24
# Libya                        22
# Other small states           21
# Liberia                      21
# Timor-Leste                  21
# Cura̤ao                     21
# Qatar                        21
# Palau                        21
# Ṣo Tom̩ and Principe      20
# ...

# %%
all_years['Country'].value_counts().loc[lambda x : x>30]
# Out:
# Least developed countries: UN classification    31
# Niger                                           31
# Middle East & North Africa (IDA & IBRD)         31
# Middle income                                   31
# Mongolia                                        31
#                                                 ..
# IDA only                                        31
# Fragile and conflict affected situations        31
# Ireland                                         31
# France                                          31
# Italy                                           31
# Name: Country, Length: 205, dtype: int64

# %% [markdown]
# 205 Countries have all 30 years and the remaining 35 Countries are missing some years of data. Smaller countries have just started reporting data.

# %% [markdown]
# 8. In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020. Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?

# %%
all_years
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
year_filt = (all_years['Year'] == 2020)

# %%
type(year_filt)
# Out:
# pandas.core.series.Series

# %%
all_years.loc[year_filt]
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 19    Africa Eastern and Southern  2020     3491.978104
# 50     Africa Western and Central  2020     4021.293919
# 81                        Albania  2020    13253.733337
# 112                       Algeria  2020    10735.382539
# ...                           ...   ...             ...
# 7025                      Vietnam  2020    10338.270543
# 7056           West Bank and Gaza  2020     5402.538773
# 7083                        World  2020    16269.969854
# 7114                       Zambia  2020     3277.816510
# 7145                     Zimbabwe  2020     2134.555461
#
# [240 rows x 3 columns]

# %%
year_2020 = all_years.loc[year_filt]

# %%
type(year_2020)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Only 240 rows, because not all countries reported data in 2020.

# %%
max_gdp = all_years['GDP_Per_Capita'].max()

# %%
max_gdp
# Out:
# 161971.46466102

# %%
min_gdp = all_years['GDP_Per_Capita'].min()

# %%
min_gdp
# Out:
# 436.720371050912

# %%
plt.hist(year_2020)
plt.ylabel('GDP_Per_Capita')
plt.xlabel('Countries')
# Out:
# Text(0.5, 0, 'Countries')

# %%
plt.show()

# %%
sns.kdeplot(year_2020['GDP_Per_Capita'])
plt.title('GDP per Country')
plt.show()

# %%
fig = plt.figure(figsize = (9,35))
ax1 = plt.subplot (111)
sns.boxplot( x=year_2020["GDP_Per_Capita"], y=year_2020["Country"] )
plt.title('GDP per Country')
# Out:
# Text(0.5, 1.0, 'GDP per Country')

# %%
yr=sns.boxplot(x=year_2020["GDP_Per_Capita"] )
plt.title('GDP per Country')
# Out:
# Text(0.5, 1.0, 'GDP per Country')

# %%
sns.violinplot(y=year_2020["GDP_Per_Capita"])
# Out:
# <AxesSubplot:ylabel='GDP_Per_Capita'>

# %% [markdown]
# The is a spike in GDP between 0 and 20,000. It appears that the majority of the countries fall within this range.

# %% [markdown]
# 9. What was the median GDP per capita value in 2020?

# %%
round(year_2020.median(), 2)
# Out:
# C:\Users\chern\AppData\Local\Temp\ipykernel_21612\3238198424.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   round(year_2020.median(), 2)
# Year               2020.00
# GDP_Per_Capita    12908.94
# dtype: float64

# %% [markdown]
# 10. For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots:
# 	* A boxplot
# 	* A barplot (check out the Barplot with Seaborn section: https://www.python-graph-gallery.com/barplot/#Seaborn)
# 	* A scatterplot
# 	* A scatterplot with a trend line overlaid (see this regplot example: https://www.python-graph-gallery.com/42-custom-linear-regression-fit-seaborn)
# Comment on what you observe has happened to GDP values over time and the relative strengths and weaknesses of each type of plot.

# %%
all_years
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
is_1990 =  all_years['Year'] == 1990

# %%
is_2000 =  all_years['Year'] == 2000

# %%
is_2010 =  all_years['Year'] == 2010

# %%
is_2020 =  all_years['Year'] == 2020

# %%
 all_years[is_1990 | is_2000 | is_2010 | is_2020]
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 10                    Afghanistan  2010     1957.029070
# 19    Africa Eastern and Southern  2020     3491.978104
# 29    Africa Eastern and Southern  2010     3545.205203
# 39    Africa Eastern and Southern  2000     2915.472987
# ...                           ...   ...             ...
# 7144                       Zambia  1990     2190.181724
# 7145                     Zimbabwe  2020     2134.555461
# 7155                     Zimbabwe  2010     1813.531764
# 7165                     Zimbabwe  2000     2771.060576
# 7175                     Zimbabwe  1990     2652.129209
#
# [918 rows x 3 columns]

# %%
gdp_decades = all_years[is_1990 | is_2000 | is_2010 | is_2020]

# %%
gdp_decades.shape
# Out:
# (918, 3)

# %%
df=gdp_decades
sns.set_style("whitegrid")

# %% [markdown]
# Boxplot

# %%
sns.boxplot(x=df["Year"], y=df["GDP_Per_Capita"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# Barplot

# %%
sns.barplot(x=df["Year"], y=df["GDP_Per_Capita"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# Scatterplot

# %%
sns.boxplot(x=df["Year"], y=df["GDP_Per_Capita"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# Scatter Plot w/ Trend line

# %%
sns.regplot(x=df["Year"], y=df["GDP_Per_Capita"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# RePlot

# %%
sns.relplot(x=df["Year"], y=df["GDP_Per_Capita"])

# %% [markdown]
# ScatterPlot

# %%
g= sns.FacetGrid(gdp_decades, col = 'Year', row = 'Country')
g.map(sns.scatterplot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21612\1849738035.py in <module>
# ----> 1 g= sns.FacetGrid(gdp_decades, col = 'Year', row = 'Country')
#       2 g.map(sns.scatterplot)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     483         # --- Make the axes look good
#     484
# --> 485         self.tight_layout()
#     486         if despine:
# ...

# %% [markdown]
# 11. Which country was the first to have a GDP per capita greater than $100,000?

# %%
high_gdp = all_years[all_years['GDP_Per_Capita'] > 100000]

# %%
high_gdp.describe()
# Out:
#               Year  GDP_Per_Capita
# count    39.000000       39.000000
# mean   2007.897436   115999.975244
# std       8.822205    14612.083577
# min    1990.000000   100100.435658
# 25%    2001.500000   105606.274460
# 50%    2010.000000   113182.728563
# 75%    2015.000000   118120.117180
# max    2020.000000   161971.464661

# %%
round(high_gdp.sort_values('Year').head(1), 2)
# Out:
#                    Country  Year  GDP_Per_Capita
# 6838  United Arab Emirates  1990       111454.06

# %% [markdown]
# 12. Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
round(year_2020.sort_values('GDP_Per_Capita', ascending=False).head(1),2)
# Out:
#          Country  Year  GDP_Per_Capita
# 3882  Luxembourg  2020       112557.31

# %%
is_lux =  all_years['Country'] == 'Luxembourg'

# %%
type(is_lux)
# Out:
# pandas.core.series.Series

# %%
lux_gdp = all_years[is_lux]

# %%
lux_gdp
# Out:
#          Country  Year  GDP_Per_Capita
# 3882  Luxembourg  2020   112557.309472
# 3883  Luxembourg  2019   116518.276815
# 3884  Luxembourg  2018   115049.926079
# 3885  Luxembourg  2017   114985.842236
# 3886  Luxembourg  2016   116283.699681
# 3887  Luxembourg  2015   113182.728563
# 3888  Luxembourg  2014   113313.578898
# 3889  Luxembourg  2013   113050.663254
# 3890  Luxembourg  2012   112137.135491
# 3891  Luxembourg  2011   112998.390477
# 3892  Luxembourg  2010   114343.988089
# 3893  Luxembourg  2009   112230.081410
# 3894  Luxembourg  2008   118154.667184
# 3895  Luxembourg  2007   120647.822959
# 3896  Luxembourg  2006   113346.035782
# 3897  Luxembourg  2005   108632.360016
# 3898  Luxembourg  2004   107634.837198
# 3899  Luxembourg  2003   104743.000088
# 3900  Luxembourg  2002   103317.331098
# 3901  Luxembourg  2001   101143.147977
# 3902  Luxembourg  2000    99301.526999
# 3903  Luxembourg  1999    94115.384035
# 3904  Luxembourg  1998    88185.800110
# ...

# %%
sns.lineplot(x=lux_gdp["Year"], y=lux_gdp["GDP_Per_Capita"])
plt.title('Luxembourg')
# Out:
# Text(0.5, 1.0, 'Luxembourg')

# %% [markdown]
# 13. Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
round(year_2020.sort_values('GDP_Per_Capita').head(1),2)
# Out:
#      Country  Year  GDP_Per_Capita
# 914  Burundi  2020          731.06

# %%
is_bur =  all_years['Country'] == 'Burundi'

# %%
type(is_bur)
# Out:
# pandas.core.series.Series

# %%
bur_gdp = all_years[is_bur]

# %%
bur_gdp
# Out:
#      Country  Year  GDP_Per_Capita
# 914  Burundi  2020      731.064074
# 915  Burundi  2019      751.443405
# 916  Burundi  2018      761.524143
# 917  Burundi  2017      773.572859
# 918  Burundi  2016      794.604340
# 919  Burundi  2015      825.205574
# 920  Burundi  2014      886.235296
# 921  Burundi  2013      877.272857
# 922  Burundi  2012      862.715651
# 923  Burundi  2011      852.502576
# 924  Burundi  2010      846.169112
# 925  Burundi  2009      831.564843
# 926  Burundi  2008      827.792334
# 927  Burundi  2007      815.908213
# 928  Burundi  2006      815.053647
# 929  Burundi  2005      798.704845
# 930  Burundi  2004      817.461177
# 931  Burundi  2003      804.884232
# 932  Burundi  2002      839.777920
# 933  Burundi  2001      826.028960
# 934  Burundi  2000      828.000479
# 935  Burundi  1999      850.046951
# 936  Burundi  1998      870.043821
# 937  Burundi  1997      839.196865
# 938  Burundi  1996      861.482899
# 939  Burundi  1995      947.822231
# ...

# %%
sns.lineplot(x=bur_gdp["Year"], y=bur_gdp["GDP_Per_Capita"])
plt.title('Burundi')
# Out:
# Text(0.5, 1.0, 'Burundi')

# %% [markdown]
# **Bonus question:** Is it true in general that countries had a higher GDP per capita in 2020 than in 1990? Which countries had lower GDP per capita in 2020 than in 1990?

# %%
all_years
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
is_1990 =  all_years['Year'] == 1990

# %%
is_2020 =  all_years['Year'] == 2020

# %%
all_years[is_1990 | is_2020]
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 19    Africa Eastern and Southern  2020     3491.978104
# 49    Africa Eastern and Southern  1990     3083.976800
# 50     Africa Western and Central  2020     4021.293919
# 80     Africa Western and Central  1990     2810.341129
# ...                           ...   ...             ...
# 7113                        World  1990     9704.621768
# 7114                       Zambia  2020     3277.816510
# 7144                       Zambia  1990     2190.181724
# 7145                     Zimbabwe  2020     2134.555461
# 7175                     Zimbabwe  1990     2652.129209
#
# [446 rows x 3 columns]

# %%
select_gdp = all_years[is_1990 | is_2020]

# %%
select_gdp
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 19    Africa Eastern and Southern  2020     3491.978104
# 49    Africa Eastern and Southern  1990     3083.976800
# 50     Africa Western and Central  2020     4021.293919
# 80     Africa Western and Central  1990     2810.341129
# ...                           ...   ...             ...
# 7113                        World  1990     9704.621768
# 7114                       Zambia  2020     3277.816510
# 7144                       Zambia  1990     2190.181724
# 7145                     Zimbabwe  2020     2134.555461
# 7175                     Zimbabwe  1990     2652.129209
#
# [446 rows x 3 columns]

# %%
sns.barplot(x=select_gdp["Year"], y=select_gdp["GDP_Per_Capita"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
ninety_gdp = all_years[is_1990]

# %%
twenty_gdp =all_years[is_2020]

# %%
fig = plt.figure(figsize = (9,35))
ax1 = plt.subplot (111)
sns.boxplot( x=select_gdp["GDP_Per_Capita"], y=select_gdp["Country"] )
# Out:
# <AxesSubplot:xlabel='GDP_Per_Capita', ylabel='Country'>

# %%
fig = plt.figure(figsize = (9,35))
ax1 = plt.subplot (111)
ninety_gdp = ninety_gdp.sort_values(['GDP_Per_Capita'], ascending=False).reset_index(drop=True)
sns.barplot( x=ninety_gdp["GDP_Per_Capita"], y=ninety_gdp["Country"] )
plt.title('1990 GDP')
# Out:
# Text(0.5, 1.0, '1990 GDP')

# %%
fig = plt.figure(figsize = (9,35))
ax1 = plt.subplot (111)
twenty_gdp = twenty_gdp.sort_values(['GDP_Per_Capita'], ascending=False).reset_index(drop=True)
sns.barplot( x=twenty_gdp["GDP_Per_Capita"], y=twenty_gdp["Country"] )
plt.title('2020 GDP')
# Out:
# Text(0.5, 1.0, '2020 GDP')

# %%
twenty_gdp
# Out:
#                       Country  Year  GDP_Per_Capita
# 0                  Luxembourg  2020   112557.309472
# 1                   Singapore  2020    94505.636160
# 2                     Ireland  2020    90789.221024
# 3                       Qatar  2020    85290.450430
# 4                     Bermuda  2020    76105.138057
# ..                        ...   ...             ...
# 235                     Niger  2020     1221.269930
# 236                   Somalia  2020     1180.965971
# 237           Dem. Rep. Congo  2020     1082.445242
# 238  Central African Republic  2020      937.856470
# 239                   Burundi  2020      731.064074
#
# [240 rows x 3 columns]

# %%
fig = plt.figure(figsize = (9,35))
ax1 = plt.subplot (111)
twenty_gdp = twenty_gdp.sort_values(['GDP_Per_Capita'], ascending=True).reset_index(drop=True)
plt.barh(twenty_gdp['Country'], twenty_gdp['GDP_Per_Capita'])
plt.title('2020 GDP')
# Out:
# Text(0.5, 1.0, '2020 GDP')

# %%
fig = plt.figure(figsize = (9,35))
ax1 = plt.subplot (111)
ninety_gdp = ninety_gdp.sort_values(['GDP_Per_Capita'], ascending=True).reset_index(drop=True)
plt.barh(ninety_gdp['Country'], ninety_gdp['GDP_Per_Capita'])
plt.title('1990 GDP')
# Out:
# Text(0.5, 1.0, '1990 GDP')
